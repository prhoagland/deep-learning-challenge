# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ['T17', 'T15', 'T29', 'T14', 'T25', 'T2', 'T12', 'T13', 'T9']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
value_counts = application_df['CLASSIFICATION'].value_counts()
filtered_counts = value_counts[value_counts > 1]
print(filtered_counts)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = value_counts[value_counts < 1000].index

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_dummy_df = pd.get_dummies(application_df, columns=['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS'])
application_dummy_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                       0
# 1       1   108590              1                       0
# 2       1     5000              0                       0
# 3       1     6692              1                       0
# 4       1   142590              1                       0
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                     1                     0                    0
# 1                     0                     0                    1
# 2                     0                     0                    0
# 3                     0                     0                    1
# 4                     0                     0                    1
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                    0                    0                    0  ...
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = application_dummy_df['IS_SUCCESSFUL']
X = application_dummy_df.drop(columns=['IS_SUCCESSFUL'])

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# X.shape

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=20, activation="relu", input_dim=43))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=20, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 20)                880
#
#  dense_1 (Dense)             (None, 20)                420
#
#  dense_2 (Dense)             (None, 1)                 21
#
# ...
# Total params: 1321 (5.16 KB)
# Trainable params: 1321 (5.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 2ms/step - loss: 0.5909 - accuracy: 0.7051
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5585 - accuracy: 0.7266
# Epoch 3/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5554 - accuracy: 0.7282
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5534 - accuracy: 0.7280
# Epoch 5/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5518 - accuracy: 0.7283
# Epoch 6/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5506 - accuracy: 0.7306
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5496 - accuracy: 0.7310
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5490 - accuracy: 0.7309
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5480 - accuracy: 0.7317
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5543 - accuracy: 0.7277 - 490ms/epoch - 2ms/step
# Loss: 0.5542969703674316, Accuracy: 0.7276967763900757

# %%
# Drop the 'CLASSIFICATION' column and convert categorical data to numeric with `pd.get_dummies`
application_df_2 = application_df.drop(columns=['CLASSIFICATION'])
application_df_2.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION      USE_CASE  ORGANIZATION  STATUS  \
# 0              T10       Independent    ProductDev   Association       1
# 1               T3       Independent  Preservation  Co-operative       1
# 2               T5  CompanySponsored    ProductDev   Association       1
# 3               T3  CompanySponsored  Preservation         Trust       1
# 4               T3       Independent     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_dummy_2 = pd.get_dummies(application_df_2, columns=['APPLICATION_TYPE', 'AFFILIATION', 'USE_CASE', 'ORGANIZATION', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS'])
application_dummy_2.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                       0
# 1       1   108590              1                       0
# 2       1     5000              0                       0
# 3       1     6692              1                       0
# 4       1   142590              1                       0
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                     1                     0                    0
# 1                     0                     0                    1
# 2                     0                     0                    0
# 3                     0                     0                    1
# 4                     0                     0                    1
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                    0                    0                    0  ...
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = application_dummy_2['IS_SUCCESSFUL']
X = application_dummy_2.drop(columns=['IS_SUCCESSFUL'])

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# X.shape

nn_2 = tf.keras.models.Sequential()

# First hidden layer
nn_2.add(tf.keras.layers.Dense(units=40, activation="relu", input_dim=37))

# Second hidden layer
nn_2.add(tf.keras.layers.Dense(units=40, activation="relu"))

# Output layer
nn_2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 40)                1520
#
#  dense_7 (Dense)             (None, 40)                1640
#
#  dense_8 (Dense)             (None, 1)                 41
#
# ...
# Total params: 3201 (12.50 KB)
# Trainable params: 3201 (12.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn_2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_2.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5831 - accuracy: 0.7174
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5709 - accuracy: 0.7257
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5689 - accuracy: 0.7247
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5683 - accuracy: 0.7273
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5670 - accuracy: 0.7269
# Epoch 6/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5672 - accuracy: 0.7278
# Epoch 7/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5664 - accuracy: 0.7280
# Epoch 8/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5662 - accuracy: 0.7274
# Epoch 9/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5654 - accuracy: 0.7269
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5729 - accuracy: 0.7219 - 510ms/epoch - 2ms/step
# Loss: 0.5728527307510376, Accuracy: 0.7218658924102783

# %%
# Split our preprocessed data into our features and target arrays
y = application_dummy_df['IS_SUCCESSFUL']
X = application_dummy_df.drop(columns=['IS_SUCCESSFUL'])

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# Add more hidden layers and neurons to each layer

nn_3 = tf.keras.models.Sequential()

# First hidden layer
nn_3.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=43))

# Second hidden layer
nn_3.add(tf.keras.layers.Dense(units=60, activation="relu"))

# Third hidden layer
nn_3.add(tf.keras.layers.Dense(units=40, activation="relu"))

# Fourth hidden layer
nn_3.add(tf.keras.layers.Dense(units=30, activation="relu"))

# Output layer
nn_3.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_3.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 80)                3520
#
#  dense_10 (Dense)            (None, 60)                4860
#
#  dense_11 (Dense)            (None, 40)                2440
#
#  dense_12 (Dense)            (None, 30)                1230
#
#  dense_13 (Dense)            (None, 1)                 31
#
# ...
# Total params: 12081 (47.19 KB)
# Trainable params: 12081 (47.19 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn_3.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_3.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5697 - accuracy: 0.7189
# Epoch 2/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5553 - accuracy: 0.7280
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5523 - accuracy: 0.7299
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5495 - accuracy: 0.7315
# Epoch 5/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5486 - accuracy: 0.7338
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5476 - accuracy: 0.7329
# Epoch 7/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5471 - accuracy: 0.7322
# Epoch 8/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5463 - accuracy: 0.7330
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5464 - accuracy: 0.7338
# Epoch 10/100
# ...

# %%
model_loss, model_accuracy = nn_3.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 2s - loss: 0.5942 - accuracy: 0.7290 - 2s/epoch - 6ms/step
# Loss: 0.5941562056541443, Accuracy: 0.7289795875549316

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# Adjust activation functions

nn_4 = tf.keras.models.Sequential()

# First hidden layer
nn_4.add(tf.keras.layers.Dense(units=80, activation="tanh", input_dim=43))

# Second hidden layer
nn_4.add(tf.keras.layers.Dense(units=60, activation="tanh"))

# Third hidden layer
nn_4.add(tf.keras.layers.Dense(units=40, activation="tanh"))

# Fourth hidden layer
nn_4.add(tf.keras.layers.Dense(units=30, activation="tanh"))

# Output layer
nn_4.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_4.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_14 (Dense)            (None, 80)                3520
#
#  dense_15 (Dense)            (None, 60)                4860
#
#  dense_16 (Dense)            (None, 40)                2440
#
#  dense_17 (Dense)            (None, 30)                1230
#
#  dense_18 (Dense)            (None, 1)                 31
#
# ...
# Total params: 12081 (47.19 KB)
# Trainable params: 12081 (47.19 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn_4.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_4.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5300 - accuracy: 0.7411
# Epoch 2/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5301 - accuracy: 0.7416
# Epoch 3/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5300 - accuracy: 0.7420
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5305 - accuracy: 0.7414
# Epoch 5/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5308 - accuracy: 0.7413
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5302 - accuracy: 0.7416
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5302 - accuracy: 0.7414
# Epoch 8/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5302 - accuracy: 0.7416
# Epoch 9/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5301 - accuracy: 0.7420
# Epoch 10/100
# ...

# %%
model_loss, model_accuracy = nn_4.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5689 - accuracy: 0.7304 - 698ms/epoch - 3ms/step
# Loss: 0.5688638687133789, Accuracy: 0.7303789854049683

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# Adjust activation functions

nn_5 = tf.keras.models.Sequential()

# First hidden layer
nn_5.add(tf.keras.layers.Dense(units=80, activation="sigmoid", input_dim=43))

# Second hidden layer
nn_5.add(tf.keras.layers.Dense(units=60, activation="sigmoid"))

# Third hidden layer
nn_5.add(tf.keras.layers.Dense(units=40, activation="sigmoid"))

# Fourth hidden layer
nn_5.add(tf.keras.layers.Dense(units=30, activation="sigmoid"))

# Output layer
nn_5.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_5.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_19 (Dense)            (None, 80)                3520
#
#  dense_20 (Dense)            (None, 60)                4860
#
#  dense_21 (Dense)            (None, 40)                2440
#
#  dense_22 (Dense)            (None, 30)                1230
#
#  dense_23 (Dense)            (None, 1)                 31
#
# ...
# Total params: 12081 (47.19 KB)
# Trainable params: 12081 (47.19 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn_5.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_5.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 3ms/step - loss: 0.6079 - accuracy: 0.6834
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5760 - accuracy: 0.7281
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5701 - accuracy: 0.7289
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5623 - accuracy: 0.7281
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5596 - accuracy: 0.7286
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5578 - accuracy: 0.7304
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5564 - accuracy: 0.7307
# Epoch 8/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5558 - accuracy: 0.7300
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5539 - accuracy: 0.7312
# Epoch 10/100
# ...

# %%
model_loss, model_accuracy = nn_5.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5589 - accuracy: 0.7322 - 723ms/epoch - 3ms/step
# Loss: 0.5589309334754944, Accuracy: 0.7322449088096619

# %%
# Drop application type as well as classification and convert categorical data to numeric with `pd.get_dummies`
application_df_3 = application_df_2.drop(columns=['APPLICATION_TYPE'])
application_dummy_3 = pd.get_dummies(application_df_3, columns=['AFFILIATION', 'USE_CASE', 'ORGANIZATION', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS'])
application_dummy_3.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  AFFILIATION_CompanySponsored  \
# 0       1     5000              1                             0
# 1       1   108590              1                             0
# 2       1     5000              0                             1
# 3       1     6692              1                             1
# 4       1   142590              1                             0
#
#    AFFILIATION_Family/Parent  AFFILIATION_Independent  AFFILIATION_National  \
# 0                          0                        1                     0
# 1                          0                        1                     0
# 2                          0                        0                     0
# 3                          0                        0                     0
# 4                          0                        1                     0
#
#    AFFILIATION_Other  AFFILIATION_Regional  USE_CASE_CommunityServ  ...  \
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = application_dummy_3['IS_SUCCESSFUL']
X = application_dummy_3.drop(columns=['IS_SUCCESSFUL'])

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# Adjust activation functions

nn_6 = tf.keras.models.Sequential()

# First hidden layer
nn_6.add(tf.keras.layers.Dense(units=80, activation="sigmoid", input_dim=28))

# Second hidden layer
nn_6.add(tf.keras.layers.Dense(units=60, activation="sigmoid"))

# Third hidden layer
nn_6.add(tf.keras.layers.Dense(units=40, activation="sigmoid"))

# Fourth hidden layer
nn_6.add(tf.keras.layers.Dense(units=30, activation="sigmoid"))

# Output layer
nn_6.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_6.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_24 (Dense)            (None, 80)                2320
#
#  dense_25 (Dense)            (None, 60)                4860
#
#  dense_26 (Dense)            (None, 40)                2440
#
#  dense_27 (Dense)            (None, 30)                1230
#
#  dense_28 (Dense)            (None, 1)                 31
#
# ...
# Total params: 10881 (42.50 KB)
# Trainable params: 10881 (42.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn_6.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_6.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.6266 - accuracy: 0.6604
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6088 - accuracy: 0.6977
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6081 - accuracy: 0.6993
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6070 - accuracy: 0.6989
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6068 - accuracy: 0.6988
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6066 - accuracy: 0.6991
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6052 - accuracy: 0.6988
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6031 - accuracy: 0.7002
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6020 - accuracy: 0.6992
# Epoch 10/100
# ...

# %%
# Export our model to HDF5 file
nn_5.save("model_optimized.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
